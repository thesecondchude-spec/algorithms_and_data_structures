# %% [markdown]
# # Practice Interview
#
# ## Objective
#
# _*The partner assignment aims to provide participants with the opportunity to practice coding in an interview context. You will analyze your partner's Assignment 1. Moreover, code reviews are common practice in a software development team. This assignment should give you a taste of the code review process.*_
#
# ## Group Size
#
# Each group should have 2 people. You will be assigned a partner
#
# ## Parts:
# - Part 1: Complete 1 of 3 questions
# - Part 2: Review your partner's Assignment 1 submission
# - Part 3: Perform code review of your partner's assignment 1 by answering the questions below
# - Part 3: Reflect on Assignment 1 and Assignment 2
#
# ## Part 1:
#
# _*You will be assigned one of three problems based of your first name. Enter your first name, in all lower case, execute the code below, and that will tell you your assigned problem. Include the output as part of your submission (do not clear the output). The problems are based-off problems from Leetcode.*_

# %%
import hashlib

def hash_to_range(input_string: str) -> int:
     hash_object = hashlib.sha256(input_string.encode())
     hash_int = int(hash_object.hexdigest(), 16)
     return (hash_int % 3) + 1
input_string = "chude"
result = hash_to_range(input_string)
print(result)
# Out:
# 1

# %% [markdown]
# <details>
#   <summary>Question 1</summary>
#
#   # Question One: Check Duplicates in Tree
#
#   Given the `root` of a binary tree, check whether it is contains a duplicate value. If a duplicate exists, return the duplicate value. If there are multiple duplicates, return the one with the closest distance to the root. If no duplicate exists, return -1.
#
#   ## Examples
#
#   ### Example 1
#
#   ![](./images/q1_ex1.png)
#
#   Input: `root = [1, 2, 2, 3, 5, 6, 7]` *What traversal method is this?*
#
#   Output: 2
#
#   ### Example 2
#
#   ![](./images/q1_ex2.png)
#
#   Input: `root = [1, 10, 2, 3, 10, 12, 12]`
#
#   Output: 10
#
#   ### Example 3
#
#   ![](./images/q1_ex3.png)
#
#   Input: `root = [10, 9, 8, 7]`
#
#   Output: -1
#
# </details>
#
# #### Starter Code for Question 1

# %%
  # Definition for a binary tree node.
class TreeNode(object):
    def __init__(self, val = 0, left = None, right = None):
        self.val = val
        self.left = left
        self.right = right

from collections import deque
from typing import Optional, List

def build_tree_from_list(values: List) -> Optional[TreeNode]:
    """
    Helper function to build a binary tree from level-order list representation.
    None values in the list represent missing nodes.
    """
    if not values:
        return None
    
    root = TreeNode(values[0])
    queue = deque([root])
    i = 1
    
    while queue and i < len(values):
        node = queue.popleft()
        
        # Add left child
        if i < len(values) and values[i] is not None:
            node.left = TreeNode(values[i])
            queue.append(node.left)
        i += 1
        
        # Add right child
        if i < len(values) and values[i] is not None:
            node.right = TreeNode(values[i])
            queue.append(node.right)
        i += 1
    
    return root

def is_duplicate(root: Optional[TreeNode]) -> int:
    """
    Find the first duplicate value in a binary tree using level-order traversal.
    Returns the duplicate closest to the root, or -1 if no duplicates exist.
    
    Time Complexity: O(n) where n is the number of nodes
    Space Complexity: O(n) for the queue and set
    """
    if not root:
        return -1
    
    # Use a set to track values we've seen
    seen = set()
    
    # Use a queue for level-order (BFS) traversal
    # This ensures we check nodes level by level, closest to root first
    queue = deque([root])
    
    while queue:
        node = queue.popleft()
        
        # Check if we've seen this value before
        if node.val in seen:
            return node.val
        
        # Mark this value as seen
        seen.add(node.val)
        
        # Add children to queue for next level
        if node.left:
            queue.append(node.left)
        if node.right:
            queue.append(node.right)
    
    # No duplicates found
    return -1

# %%
# Test cases
print("Example 1:")
root1 = build_tree_from_list([1, 2, 2, 3, 5, 6, 7])
print(f"Input: [1, 2, 2, 3, 5, 6, 7]")
print(f"Output: {is_duplicate(root1)}")
print(f"Expected: 2\n")

print("Example 2:")
root2 = build_tree_from_list([1, 10, 2, 3, 10, 12, 12])
print(f"Input: [1, 10, 2, 3, 10, 12, 12]")
print(f"Output: {is_duplicate(root2)}")
print(f"Expected: 10\n")

print("Example 3:")
root3 = build_tree_from_list([10, 9, 8, 7])
print(f"Input: [10, 9, 8, 7]")
print(f"Output: {is_duplicate(root3)}")
print(f"Expected: -1")
# Out:
# Example 1:
# Input: [1, 2, 2, 3, 5, 6, 7]
# Output: 2
# Expected: 2
#
# Example 2:
# Input: [1, 10, 2, 3, 10, 12, 12]
# Output: 10
# Expected: 10
#
# Example 3:
# Input: [10, 9, 8, 7]
# Output: -1
# Expected: -1

# %% [markdown]
# <details>
#   <summary>Question 2</summary>
#
#   # Question Two: Path to Leaves
#
#   Given the `root` of a binary tree, return all root to leaf paths in any order.
#
#   ## Examples
#
#   ### Example 1
#
#   ![](./images/q1_ex1.png)
#
#   Input: `root = [1, 2, 2, 3, 5, 6, 7]` *What traversal method is this?*
#
#   Output: [[1, 2, 3], [1, 2, 5], [1, 2, 6], [1, 2, 7]]
#
#   ### Example 2
#
#   ![](./images/q1_ex3.png)
#
#   Input: `root = [10, 9, 7, 8]`
#
#   Output: [[10, 7], [10, 9, 8]]
#
# </details>
#
# #### Starter Code for Question 2

# %%
# Definition for a binary tree node.
# class TreeNode(object):
#     def __init__(self, val = 0, left = None, right = None):
#         self.val = val
#         self.left = left
#         self.right = right
def bt_path(root: TreeNode) -> List[List[int]]:
  # TODO

# %% [markdown]
# <details>
#   <summary>Question 3</summary>
#
#   # Question Three: Missing Number in Range
#
#   You are given a list containing `n` integers in the range `[0, n]`. Return a list of numbers that are missing from the range `[0, n]` of the array. If there is no missing number, return -1. Note, all the integers in the list may not be unique.
#
#   ## Examples
#
#   ### Example 1
#
#   Input: `lst = [0, 2]`
#
#   Output: [1]
#
#   ### Example 2
#
#   Input: `lst = [5, 0, 1]`
#
#   Output: [2, 3, 4]
#
#   ### Example 3
#
#   Input: `lst = [6, 8, 2, 3, 5, 7, 0, 1, 10]`
#
#   Output: [4, 9]
#
# </details>
#
# #### Starter Code for Question 3

# %%
def missing_num(nums: List) -> int:
  # TODO

# %% [markdown]
# ## Part 2:
#
# You and your partner must share each other's Assignment 1 submission.

# %% [markdown]
# ## Part 3:
#
# Create a Jupyter Notebook, create 6 of the following headings, and complete the following for your partner's assignment 1:
#
# -   Paraphrase the problem in your own words.

# %%
# Your answer here
### Paraphrase the problem

#The problem asks us to find the first value in a list that appears more than once. 
#We need to scan through the list from left to right, and when we encounter a number that we have already seen before, 
#we return that number immediately. If we reach the end of the list without finding any duplicates, then we return -1. 
#The key is that we want the FIRST duplicate encountered as we traverse the list, not necessarily the value that appears earliest in the list.

# %% [markdown]
# -   Create 1 new example that demonstrates you understand the problem. Trace/walkthrough 1 example that your partner made and explain it.

# %%
# example of my partner's solution
my_str = "{}[{()}]"

# %% [markdown]
# -   Copy the solution your partner wrote.

# %%
# Your answer here
from typing import List

def first_duplicate(nums: List[int]) -> int:
    index = 0
    for num in nums:
        if num in nums[index + 1:]:
            return num
        index += 1
    return -1

first_duplicate([6, 2, 1, 3, 3, 5, 2, 1]) \
,first_duplicate([1, 3, 2, 8]) \
,first_duplicate([3, 2, 9, 23, 45, 1, 7, 7])
# Out:
# (2, -1, 7)

# %% [markdown]
# -   Explain why their solution works in your own words.

# %%
### Why the Solution Works

#The solution works by iterating through each element in the list and checking if that element appears anywhere in the remaining portion of the list (after the current position). 
# This is accomplished using list slicing `nums[index + 1:]` which creates a sublist containing all elements after the current index.
#For each element at position `index`, the code checks if that same value exists in the rest of the list. If it does, this means we've found a duplicate, and since we're scanning from left to right, this is the first element that has a duplicate. The function immediately returns this value.
#If we complete the entire loop without finding any duplicates, the function returns -1 to indicate no duplicates exist.
#The key insight is that by checking only the portion of the list that comes AFTER the current element, we ensure we find duplicates and we find them in the order they first appear.

# %% [markdown]
# -   Explain the problem’s time and space complexity in your own words.

# %%
# Your answer here
# The problem's time complexity is O(n) as the loop checks once the string for n elements. The space complexity is O(n) in the worst case when all characters are opening brackets and are stored in the stack.

# %% [markdown]
# -   Critique your partner's solution, including explanation, and if there is anything that should be adjusted.

# %%
# Your answer here
# I think my partner did a good job in solving the problem. The solution is efficient and correctly checks for valid bracket sequences. It handles edge cases, such as odd-length strings, and uses a stack to ensure that brackets are properly matched. Overall, I would say that my partner's solution was implemented well and effective for the given problem.

# %% [markdown]
# ## Part 4:
#
# Please write a 200 word reflection documenting your process from assignment 1, and your presentation and review experience with your partner at the bottom of the Jupyter Notebook under a new heading "Reflection." Again, export this Notebook as pdf.

# %% [markdown]
# ### Reflection

# %%
# Your answer here

#This reflection summarizes my experience with Assignment 1 and the overall learning process. I found the assignment both engaging and intellectually stimulating. It challenged me to think critically about the problems presented and apply my knowledge of algorithms and data structures in a practical way. The tasks required careful analysis, logical reasoning, and thoughtful implementation.
#I especially appreciated the opportunity to collaborate with a partner. Working together allowed us to exchange ideas, compare approaches, and learn from each other’s perspectives. My partner’s problem-solving methods were insightful and introduced me to alternative ways of thinking about the same challenges. This experience reinforced the idea that multiple approaches can often lead to effective solutions.
#Overall, the assignment was a valuable learning experience that deepened my understanding of core computer science concepts. Studying data structures and algorithms has been eye-opening, as it has strengthened my ability to design efficient solutions and optimize code. Through this course, I have gained a stronger grasp of fundamental structures such as arrays, linked lists, stacks, queues, trees, and graphs, along with essential algorithms for sorting, searching, and traversal.
#I am grateful for the opportunity to build this foundational knowledge and look forward to applying what I have learned in future assignments and projects.

# %% [markdown]
# ## Evaluation Criteria
#
# We are looking for the similar points as Assignment 1
#
# -   Problem is accurately stated
#
# -   New example is correct and easily understandable
#
# -   Correctness, time, and space complexity of the coding solution
#
# -   Clarity in explaining why the solution works, its time and space complexity
#
# -   Quality of critique of your partner's assignment, if necessary

# %% [markdown]
# ## Submission Information
#
# 🚨 **Please review our [Assignment Submission Guide](https://github.com/UofT-DSI/onboarding/blob/main/onboarding_documents/submissions.md)** 🚨 for detailed instructions on how to format, branch, and submit your work. Following these guidelines is crucial for your submissions to be evaluated correctly.
#
# ### Submission Parameters:
# * Submission Due Date: `HH:MM AM/PM - DD/MM/YYYY`
# * The branch name for your repo should be: `assignment-2`
# * What to submit for this assignment:
#     * This Jupyter Notebook (assignment_2.ipynb) should be populated and should be the only change in your pull request.
# * What the pull request link should look like for this assignment: `https://github.com/<your_github_username>/algorithms_and_data_structures/pull/<pr_id>`
#     * Open a private window in your browser. Copy and paste the link to your pull request into the address bar. Make sure you can see your pull request properly. This helps the technical facilitator and learning support staff review your submission easily.
#
# Checklist:
# - [ ] Created a branch with the correct naming convention.
# - [ ] Ensured that the repository is public.
# - [ ] Reviewed the PR description guidelines and adhered to them.
# - [ ] Verify that the link is accessible in a private browser window.
#
# If you encounter any difficulties or have questions, please don't hesitate to reach out to our team via our Slack at `#cohort-6-help`. Our Technical Facilitators and Learning Support staff are here to help you navigate any challenges.
